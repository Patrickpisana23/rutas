# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv', delimiter=';')
data.head()
# Out:
#    ANOPRO TIPO_COMBUSTIBLE        VALE NOMBRE_PLACA  \
# 0    2019       GASOHOL 90  1000393508      EAA-207
# 1    2019       GASOHOL 90  1000393538      PGQ-764
# 2    2019       GASOHOL 90  1000393610      EA-2220
# 3    2019       GASOHOL 90  1000393605      PGQ-766
# 4    2019       GASOHOL 90  1000393694      EAA-726
#
#                                      UNIDAD_ORGANICA  KM_RECORRIDO  \
# 0          GERENCIA DE DESARROLLO E INCLUSION SOCIAL         500.0
# 1     SUB GERENCIA DE TRANSITO TRANSPORTE Y VIALIDAD         500.0
# 2  SUB GERENCIA DE GESTION Y MANEJO DE RESIDUOS S...         200.0
# 3                  SGGRD-INSPECCION DE EDIFICACIONES         500.0
# 4     SUB GERENCIA DE TRANSITO TRANSPORTE Y VIALIDAD         500.0
#
#    CANTIDAD_GALONES  PRECIO  TOTAL_CONSUMO  FECHA_INGRESO_VALE FECHA_SOAT  \
# 0             10.00   14.67         146.70          20190328.0   20200325
# 1              6.00   14.67          88.02          20190328.0   20200325
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132280 entries, 0 to 132279
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ANOPRO              132280 non-null  int64
#  1   TIPO_COMBUSTIBLE    132280 non-null  object
#  2   VALE                132280 non-null  int64
#  3   NOMBRE_PLACA        132280 non-null  object
#  4   UNIDAD_ORGANICA     132279 non-null  object
#  5   KM_RECORRIDO        132280 non-null  float64
#  6   CANTIDAD_GALONES    132280 non-null  float64
#  7   PRECIO              132280 non-null  float64
#  8   TOTAL_CONSUMO       132280 non-null  float64
#  9   FECHA_INGRESO_VALE  132280 non-null  float64
#  10  FECHA_SOAT          132280 non-null  object
#  11  DEPARTAMENTO        132280 non-null  object
#  12  PROVINCIA           132280 non-null  object
#  13  DISTRITO            132280 non-null  object
#  14  UBIGEO              132280 non-null  object
# ...

# %%
data.info()

# %%
data.describe()

# %%
data['TIPO_COMBUSTIBLE']

# %%
set(data['TIPO_COMBUSTIBLE'])
# Out:
# {'DIESEL B5 S-50', 'GASOHOL 90', 'GNV'}

# %%
set(data['DISTRITO'])
# Out:
# {'150103', 'ATE', 'LIMA'}

# %%
data['DISTRITO'].astype
# Out:
# <bound method NDFrame.astype of 0            ATE
# 1            ATE
# 2            ATE
# 3            ATE
# 4            ATE
#            ...
# 132275       ATE
# 132276       ATE
# 132277    150103
# 132278       ATE
# 132279       ATE
# Name: DISTRITO, Length: 132280, dtype: object>

# %%
distritos_no=['LIMA','ATE']
data = data[data['DISTRITO'].isin(distritos_no)]

# %%
set(data['DISTRITO'])
# Out:
# {'ATE', 'LIMA'}

# %%
data=data.drop('Unnamed: 16', axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data['TIPO_COMBUSTIBLE'])
plt.show()

# %%
data.head()

# %%
data.head()

# %%
valores_repetidos = data['NOMBRE_PLACA'].value_counts()
valores_repetidos
# Out:
# NOMBRE_PLACA
# EGZ-671     1352
# EUE-836     1274
# EUE-829     1274
# EUE-825     1270
# EGZ-721     1261
#             ...
# MG-34743       1
# AVW-759        1
# EGE-199        1
# OO-8849        1
# EUA-039        1
# Name: count, Length: 314, dtype: int64

# %%
data = data[data['KM_RECORRIDO']!=1] 
data.head()
# Out:
#    ANOPRO TIPO_COMBUSTIBLE        VALE NOMBRE_PLACA  \
# 0    2019       GASOHOL 90  1000393508      EAA-207
# 1    2019       GASOHOL 90  1000393538      PGQ-764
# 2    2019       GASOHOL 90  1000393610      EA-2220
# 3    2019       GASOHOL 90  1000393605      PGQ-766
# 4    2019       GASOHOL 90  1000393694      EAA-726
#
#                                      UNIDAD_ORGANICA  KM_RECORRIDO  \
# 0          GERENCIA DE DESARROLLO E INCLUSION SOCIAL         500.0
# 1     SUB GERENCIA DE TRANSITO TRANSPORTE Y VIALIDAD         500.0
# 2  SUB GERENCIA DE GESTION Y MANEJO DE RESIDUOS S...         200.0
# 3                  SGGRD-INSPECCION DE EDIFICACIONES         500.0
# 4     SUB GERENCIA DE TRANSITO TRANSPORTE Y VIALIDAD         500.0
#
#    CANTIDAD_GALONES  PRECIO  TOTAL_CONSUMO  FECHA_INGRESO_VALE FECHA_SOAT  \
# 0             10.00   14.67         146.70          20190328.0   20200325
# 1              6.00   14.67          88.02          20190328.0   20200325
# ...

# %%
data = data[data['KM_RECORRIDO']!=0]

# %%
data = data[data['TOTAL_CONSUMO']<0] 
data
# Out:
# Empty DataFrame
# Columns: [ANOPRO, TIPO_COMBUSTIBLE, VALE, NOMBRE_PLACA, UNIDAD_ORGANICA, KM_RECORRIDO, CANTIDAD_GALONES, PRECIO, TOTAL_CONSUMO, FECHA_INGRESO_VALE, FECHA_SOAT, DEPARTAMENTO, PROVINCIA, DISTRITO, UBIGEO, FECHA_CORTE]
# Index: []

# %%
data = data[data['PRECIO']<0.25] 
data

# %%
data.head()

# %%
sns.scatterplot(x="KM_RECORRIDO", y="CANTIDAD_GALONES", data=data, hue="TIPO_COMBUSTIBLE", hue_order=["DIESEL B5 S-50", "GASOHOL 90","GNV"],  style="TIPO_COMBUSTIBLE")
plt.show()

# %%
data.head()

# %%
sns.countplot(x="DISTRITO", hue="TIPO_COMBUSTIBLE", data=data)
plt.show()

# %%
sns.relplot(x="PRECIO", y="TOTAL_CONSUMO", data=data, size="TIPO_COMBUSTIBLE", kind="scatter", hue="TIPO_COMBUSTIBLE")
plt.show()

# %%
usuarios_gnv = data[data['TIPO_COMBUSTIBLE'] == 'GNV']

# Mostrar los primeros registros de los usuarios que usan GNV
print(usuarios_gnv.head())
# Out:
#      ANOPRO TIPO_COMBUSTIBLE        VALE NOMBRE_PLACA  \
# 123    2019              GNV  3000008821      EGZ-913
# 124    2019              GNV  3000008830      EGZ-913
# 125    2019              GNV  3000008852      EGZ-913
# 126    2019              GNV  3000008856      EGZ-913
# 127    2019              GNV  3000008858      EGZ-913
#
#                                      UNIDAD_ORGANICA  KM_RECORRIDO  \
# 123  SUB GERENCIA DE CONTROL OPERACIONES Y SANCIONES         120.0
# 124  SUB GERENCIA DE CONTROL OPERACIONES Y SANCIONES         120.0
# 125  SUB GERENCIA DE CONTROL OPERACIONES Y SANCIONES         120.0
# 126  SUB GERENCIA DE CONTROL OPERACIONES Y SANCIONES         120.0
# 127  SUB GERENCIA DE CONTROL OPERACIONES Y SANCIONES         120.0
#
#      CANTIDAD_GALONES  PRECIO  TOTAL_CONSUMO  FECHA_INGRESO_VALE FECHA_SOAT  \
# 123             35.39     1.6          56.62          20190702.0   20200325
# 124             38.57     1.6          61.71          20190710.0   20200325
# ...
